# %% [markdown]
# # R Programming

# %% [markdown]
# # Portfolio 1

# %%
install.packages("tidyverse")
install.packages("data.table")
install.packages("modeest")
library(tidyr)
library(ggplot2)
library(dplyr)
library(stringr)
library(data.table)
library(modeest)
# Out:
# Installing package into 'C:/Users/khala/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\khala\AppData\Local\Temp\Rtmp4gu1tR\downloaded_packages
# Warning message:
# "package 'data.table' is in use and will not be installed"
# Warning message:
# "package 'modeest' is in use and will not be installed"

# %% [markdown]
# ### The tidyr::who dataset contains tuberculosis (TB) cases broken down by year, country, age, gender, and diagnosis method. The data comes from the 2014 World Health Organization Global Tuberculosis Report

# %%
tidyr::who #Shows the who dataset
# Out:
#      country     iso2 iso3 year new_sp_m014 new_sp_m1524 new_sp_m2534
# 1    Afghanistan AF   AFG  1980  NA          NA           NA
# 2    Afghanistan AF   AFG  1981  NA          NA           NA
# 3    Afghanistan AF   AFG  1982  NA          NA           NA
# 4    Afghanistan AF   AFG  1983  NA          NA           NA
# 5    Afghanistan AF   AFG  1984  NA          NA           NA
# 6    Afghanistan AF   AFG  1985  NA          NA           NA
# 7    Afghanistan AF   AFG  1986  NA          NA           NA
# 8    Afghanistan AF   AFG  1987  NA          NA           NA
# 9    Afghanistan AF   AFG  1988  NA          NA           NA
# 10   Afghanistan AF   AFG  1989  NA          NA           NA
# 11   Afghanistan AF   AFG  1990  NA          NA           NA
# 12   Afghanistan AF   AFG  1991  NA          NA           NA
# 13   Afghanistan AF   AFG  1992  NA          NA           NA
# 14   Afghanistan AF   AFG  1993  NA          NA           NA
# ...

# %% [markdown]
# ***There are 7240 rows and 60 columns in the above dataset of who.

# %% [markdown]
# ### 1.Gather together all the columns from _new_spm014 to _newrelf65

# %%
who1 <- who %>% 
  pivot_longer(
    cols = starts_with("new"), #Columns starts with new 
    names_to = "Key",  #new column name for all that columns gathers
    values_to = "Cases", # columns name for all values
    values_drop_na = TRUE  # Drops rows that correspond to missing values
  )

# %% [markdown]
# The above code gathers all columns start with "new" prefix into new column as "Key"
# and its value as column "Cases" and drops rows that correspond to missing values

# %%
who1 #The new Dataset agthers all the columns as new key column "Key" with its values as"Cases"
# Out:
#       country     iso2 iso3 year Key          Cases
# 1     Afghanistan AF   AFG  1997 new_sp_m014    0
# 2     Afghanistan AF   AFG  1997 new_sp_m1524  10
# 3     Afghanistan AF   AFG  1997 new_sp_m2534   6
# 4     Afghanistan AF   AFG  1997 new_sp_m3544   3
# 5     Afghanistan AF   AFG  1997 new_sp_m4554   5
# 6     Afghanistan AF   AFG  1997 new_sp_m5564   2
# 7     Afghanistan AF   AFG  1997 new_sp_m65     0
# 8     Afghanistan AF   AFG  1997 new_sp_f014    5
# 9     Afghanistan AF   AFG  1997 new_sp_f1524  38
# 10    Afghanistan AF   AFG  1997 new_sp_f2534  36
# 11    Afghanistan AF   AFG  1997 new_sp_f3544  14
# 12    Afghanistan AF   AFG  1997 new_sp_f4554   8
# 13    Afghanistan AF   AFG  1997 new_sp_f5564   0
# 14    Afghanistan AF   AFG  1997 new_sp_f65     1
# 15    Afghanistan AF   AFG  1998 new_sp_m014   30
# 16    Afghanistan AF   AFG  1998 new_sp_m1524 129
# 17    Afghanistan AF   AFG  1998 new_sp_m2534 128
# 18    Afghanistan AF   AFG  1998 new_sp_m3544  90
# ...

# %% [markdown]
# After gathering columns into one column key the dimension of data is 76046(rows) × 6(columns).

# %% [markdown]
# ### 2.Make variable names consistent Instead of _newrel we have newrel. It is hard to spot this here but if you do not fix it,we will get errors in subsequent steps.

# %%
who1$Key <- str_replace(who1$Key,'newrel','new_rel') # Replace String "newrel" with "new_rel"

# %%
who2 <- who1 
who2
# Out:
#       country     iso2 iso3 year Key           Cases
# 1     Afghanistan AF   AFG  1997 new_sp_m014     0
# 2     Afghanistan AF   AFG  1997 new_sp_m1524   10
# 3     Afghanistan AF   AFG  1997 new_sp_m2534    6
# 4     Afghanistan AF   AFG  1997 new_sp_m3544    3
# 5     Afghanistan AF   AFG  1997 new_sp_m4554    5
# 6     Afghanistan AF   AFG  1997 new_sp_m5564    2
# 7     Afghanistan AF   AFG  1997 new_sp_m65      0
# 8     Afghanistan AF   AFG  1997 new_sp_f014     5
# 9     Afghanistan AF   AFG  1997 new_sp_f1524   38
# 10    Afghanistan AF   AFG  1997 new_sp_f2534   36
# 11    Afghanistan AF   AFG  1997 new_sp_f3544   14
# 12    Afghanistan AF   AFG  1997 new_sp_f4554    8
# 13    Afghanistan AF   AFG  1997 new_sp_f5564    0
# 14    Afghanistan AF   AFG  1997 new_sp_f65      1
# 15    Afghanistan AF   AFG  1998 new_sp_m014    30
# 16    Afghanistan AF   AFG  1998 new_sp_m1524  129
# 17    Afghanistan AF   AFG  1998 new_sp_m2534  128
# ...

# %% [markdown]
# The who2 is new dataset afeter replacing the sring String "newrel" with "new_rel" of column Key

# %% [markdown]
# ### 3. Run the following code
# ### whο3 <- who2 %>%
# ### separate(key, c("new", "type", "sexage"), sep = "_")
# ### Now you get a dataset who3. Comment these two lines of code. What is the purpose of using %>%.

# %%
who3  <- who2 %>% separate(Key, c("new", "type", "sexage"), sep = "_")

# %% [markdown]
# The above code separate the one column into three column by "_" using separate function.
# The purpose of the %>% is that its work as a pipe for the data. it passes the left hand side of the operator to the first argument of the right hand side of the operator. In the above code, the data frame who2 gets passed to separate().

# %%
who3
# Out:
#       country     iso2 iso3 year new type sexage Cases
# 1     Afghanistan AF   AFG  1997 new sp   m014     0
# 2     Afghanistan AF   AFG  1997 new sp   m1524   10
# 3     Afghanistan AF   AFG  1997 new sp   m2534    6
# 4     Afghanistan AF   AFG  1997 new sp   m3544    3
# 5     Afghanistan AF   AFG  1997 new sp   m4554    5
# 6     Afghanistan AF   AFG  1997 new sp   m5564    2
# 7     Afghanistan AF   AFG  1997 new sp   m65      0
# 8     Afghanistan AF   AFG  1997 new sp   f014     5
# 9     Afghanistan AF   AFG  1997 new sp   f1524   38
# 10    Afghanistan AF   AFG  1997 new sp   f2534   36
# 11    Afghanistan AF   AFG  1997 new sp   f3544   14
# 12    Afghanistan AF   AFG  1997 new sp   f4554    8
# 13    Afghanistan AF   AFG  1997 new sp   f5564    0
# 14    Afghanistan AF   AFG  1997 new sp   f65      1
# 15    Afghanistan AF   AFG  1998 new sp   m014    30
# 16    Afghanistan AF   AFG  1998 new sp   m1524  129
# 17    Afghanistan AF   AFG  1998 new sp   m2534  128
# ...

# %% [markdown]
# ### 4.Separate sexage into sex and age: Use the function separate(). Name the dataset who4

# %%
who4 <- (separate(who3, col=sexage, into=c("sex","age"), sep='(?<=[a-zA-Z])(?=[0-9])'))

# %% [markdown]
# The above code separate the sexage column into two column sex and age by numeric and alpha regular expression using separate function.

# %% [markdown]
# ### 5.Print the first 5 rows and the last 5 rows of the dataset who4 to the screen.

# %%
head(who4) #shows the first 6 data from the datafarme who4
tail(who4) #shows the last 6 data from the datafarme who4
# Out:
#   country     iso2 iso3 year new type sex age  Cases
# 1 Afghanistan AF   AFG  1997 new sp   m   014   0
# 2 Afghanistan AF   AFG  1997 new sp   m   1524 10
# 3 Afghanistan AF   AFG  1997 new sp   m   2534  6
# 4 Afghanistan AF   AFG  1997 new sp   m   3544  3
# 5 Afghanistan AF   AFG  1997 new sp   m   4554  5
# 6 Afghanistan AF   AFG  1997 new sp   m   5564  2
#   country  iso2 iso3 year new type sex age  Cases
# 1 Zimbabwe ZW   ZWE  2013 new rel  f   1524 2069
# 2 Zimbabwe ZW   ZWE  2013 new rel  f   2534 4649
# 3 Zimbabwe ZW   ZWE  2013 new rel  f   3544 3526
# 4 Zimbabwe ZW   ZWE  2013 new rel  f   4554 1453
# 5 Zimbabwe ZW   ZWE  2013 new rel  f   5564  811
# 6 Zimbabwe ZW   ZWE  2013 new rel  f   65    725

# %% [markdown]
# ### 6.Export who4 as an csv file and save it in your local directory.

# %%
fwrite(who4, "C:/Users/khala/OneDrive/Desktop/who.csv") #saved file in my local directory

# %% [markdown]
# The above fwrite function id much better and faster then read_csv and other function

# %% [markdown]
# # Portfolio 2

# %%
# Print the first 6 rows

head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
df_iris=iris
df_iris # Iris  Dataset
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %% [markdown]
# The above dataset is for Iris which show the different species by its different attributes such as
# Sepal.Length,Sepal.Width,Petal.Length and Petal.Width.

# %%
new_df_iris <- na.omit(df_iris) #remove NA values
new_df_iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %% [markdown]
# From above dataset we can notice that this dataset doesnot contain NA values

# %% [markdown]
# ### Q1. Compute the mean, median and mode of sepal length

# %%
paste("mean of speal.Length is:", mean(new_df_iris$Sepal.Length)) #the function mean()find mean of the column
paste("median of speal.Length is:",median(new_df_iris$Sepal.Length)) #the function median()find median value of the column
paste("mode of speal.Length is:",mfv(new_df_iris$Sepal.Length)) #the function mfv()find mode  of the column
# Out:
# [1] "mean of speal.Length is: 5.84333333333333"
# [1] "median of speal.Length is: 5.8"
# [1] "mode of speal.Length is: 5"

# %% [markdown]
# ### Q2. Compute how “spread out” the data are. Here you need to calculate the minimum, maximum and range of sepal length

# %%
paste("Minimum value of speal.Length is:",min(new_df_iris$Sepal.Length)) #Minimum value of the column
paste("Maximum value of speal.Length is:",max(new_df_iris$Sepal.Length)) #Maximum value of the column
paste("The range of speal.Length is:",range(new_df_iris$Sepal.Length)) #range() function fine the maximum and minimum value of the column
# Out:
# [1] "Minimum value of speal.Length is: 4.3"
# [1] "Maximum value of speal.Length is: 7.9"
# [1] "The range of speal.Length is: 4.3" "The range of speal.Length is: 7.9"

# %% [markdown]
# ### Q3. Calculate the interquartile (IQR) range of sepal length. Use the function quantile() to measure quantiles for the same variable, sepal length, and comment what is the difference and relation of these two functions regarding the results shown on your screen?

# %%
summary(new_df_iris$Sepal.Length)
paste("The interquartile(IQR) of speal.Length is:",IQR(new_df_iris$Sepal.Length))
paste("The quantile of speal.Length is:",quantile(new_df_iris$Sepal.Length))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.300   5.100   5.800   5.843   6.400   7.900
# [1] "The interquartile(IQR) of speal.Length is: 1.3"
# [1] "The quantile of speal.Length is: 4.3"
# [2] "The quantile of speal.Length is: 5.1"
# [3] "The quantile of speal.Length is: 5.8"
# [4] "The quantile of speal.Length is: 6.4"
# [5] "The quantile of speal.Length is: 7.9"

# %% [markdown]
# Quantiles are points in a distribution that relate to the rank order of values in that distribution.The middle value(middle quantile, 50th quartile) is known as the median. The first and last values is limit, the minimum and maximum values. the second and 4th values are lower quartile(25th quartile) and upper quartile((75th quartile) of the data.
#
# However the interquartile(IQR) is the upper quartile((75th quartile) - lower quartile(25th quartile) of the data.

# %% [markdown]
# ### Q4. Compute the variance and standard deviation of sepal length

# %%
paste("The variance of speal.Length is:",var(new_df_iris$Sepal.Length)) # the function var() finds the variance of the data
paste("The standard variance of speal.Length is:",sd(new_df_iris$Sepal.Length)) # the function sd() finds the standard deviation of the data
# Out:
# [1] "The variance of speal.Length is: 0.685693512304251"
# [1] "The standard variance of speal.Length is: 0.828066127977863"

# %% [markdown]
# ### Q5. Choose the right function to show min, max, mean, median, 1st and 3rd quantiles all at once of the variable sepal length

# %%
summary(new_df_iris$Sepal.Length) #This function summary() gives descriptiv statistics of the column sepal.length.
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.300   5.100   5.800   5.843   6.400   7.900

# %% [markdown]
# ### Q6. Use sapply() to compute the mean and quantiles  of each column in the dataset iris.

# %%
colMeans(new_df_iris[sapply(new_df_iris, is.numeric)]) #the function clsMeans() Use to find mean of all columns 
sapply(new_df_iris[,1:4],quantile) #The below table shows the all columns quantile
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width
#     5.843333     3.057333     3.758000     1.199333
#      Sepal.Length Sepal.Width Petal.Length Petal.Width
# 0%   4.3          2.0         1.00         0.1
# 25%  5.1          2.8         1.60         0.3
# 50%  5.8          3.0         4.35         1.3
# 75%  6.4          3.3         5.10         1.8
# 100% 7.9          4.4         6.90         2.5

# %% [markdown]
# ### Q7. Use the in-built R basic functions (no need to import any library) to create a histogram for sepal length. Make sure you add the following arguments:

# %%
hist(new_df_iris$Sepal.Length,
      main='Histogram for sepal length',
        xlab='Sepal Length',
        col='green',
        border='blue') # Plot hsitogram using hist() function
# Out:
# Plot with title "Histogram for sepal length"

# %% [markdown]
# The histogram is used to evaluate the distribution of the data.
# The above histogram gram graph we can notice that the graph is for sepal Length of the species.
# The green vertical line indicates the bin, y-axis shows the frequency of the sepal legth data
# and x-axis shows the values of the sepal Length.We can notice from the above histogram that the maximum sepal.length is between 5.5 to 6.5.

# %% [markdown]
# ### Q8. Use the in-built R basic function to create one boxplot for sepal length, sepal width, petal length and petal width

# %%
boxplot(new_df_iris[,1:4],
        main="Box-Plot for Iris",
        col='green',
        border='black')
# Out:
# Plot with title "Box-Plot for Iris"

# %% [markdown]
# Box plots can be used to compare variables, particularly for illustrating median/spread between different groups of data.
# The above graph shows the Box-plot graph for the sepal length, sepal width, petal length and petal width of the Iris data.
# The box shows the Interquartile of the data.
# The middle line between box represents the median of the data, the portion of the box beside the median it shows the upper quartile and lower quartile of the data,the two vertical line shows the range of the data, the bubble outside the range shows
# the outliers.
# It can be seen from the graph that the Sepal.Width has the outliers in its data.

# %% [markdown]
# ### Q9. The R base functions qqnorm() and qqplot() are used to produce quantile-quantile plots:
# ### • qqnorm(): produces a normal QQ plot of the variable
# ### • qqline(): adds a reference lineUse these two functions to create a QQ plot for sepal length.
# ### You will need to set the reference line colour as green, and its width as 2)

# %%
qqnorm(new_df_iris$Sepal.Length)
qqline(new_df_iris$Sepal.Length,col='green', lwd=2)
# Out:
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# From the above plot It can be notice that the QQplot is not following the straight QQline, indicating that the sepal Length is not distribted normally.

# %% [markdown]
# # R Programming Portfolio 3

# %% [markdown]
# ggplot2::ggplot() // use a function defined in ggplot2
# ggplot2::mpg //load a dataset from package ggplot2

# %%
mpg=ggplot2::mpg
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
summary(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
# ...

# %% [markdown]
# ### Q1. Plot and explain: Which vehicle brand (or manufacturer), offers the best mpg in both city and in the highway?

# %%
mpg_cityHwy <- ggplot(mpg, aes(cty, hwy))
mpg_cityHwy + geom_point(aes(colour = manufacturer))+
  stat_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# The above scatter plots give a great view of best mpg offers by both city and highway.The x-axis shows the city mpg(Miles per gallon) and y-axis shows the highway mpg where mapping vehicle manufacturing company as a color aesthetic with regression line . It can be notice from the above scatter plots that the Vehicle company ***Volkswagen*** has the highest mpg performance in both city is 35 and highway is 44 compares to other vehicle brands.

# %% [markdown]
# ### Q2. Plot and explain: Which type of car, regarding their displ range (size of engine) has the lowest mpg in the city categorised by the vehicle type (e.g., compact, suv or 2seaters defined in the variable class)?

# %%
mpg_displ <- ggplot(mpg, aes(displ,cty,color=class))
mpg_displ + facet_wrap(~ class)+ geom_point()
# Out:
# plot without title

# %% [markdown]
# The above scatter plots give a great view of how mpg decrease with high dispacement range of vehicles(size of engine)in city. The x-axis shows the displacement range and y-axis shows the city mpg however the data is categorised by vehicle types using facet_wrap() function.Facets split our plot into facets(subplots) that each displays one subset of the data.here we have used single variable so we have used facet_wrap(). from above chart, we can clearly notice that the ***SUV and pickup*** has the lowest mpg which is 9 in city with its size of the engine which is 4.7.

# %% [markdown]
# ### Q3.Plot and explain: Which type of car, regarding their displ range (size of engine) has the best mpg performance in both city and highway? Display the resulting plot categorised by the number of cylinders and the drive type (the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd). You are a buyer who wants a high litre engine vehicle and drives mostly in the highway, which type of car would you choose?

# %%
ggplot(data=mpg)+

geom_point(aes(x = displ , y = hwy,color = "hwy"))+

geom_point( aes(x = displ, y = cty,color = "cty"))+ 

facet_grid(cyl ~ drv~ class)

#scatterplot_class <-ggplot(mpg, aes(x = cty , y = hwy))

#scatterplot_class + geom_point( aes(color = class))+ 
#facet_grid(cyl ~ drv ~  displ )
# Out:
# plot without title

# %% [markdown]
# Above scatter plot describes the mpg performance of both city and highway and with thier displacement range and it is categorised by cylinder size of the vehicle and vehicle types. The x-axis show the displacement range and y -axis shows the highway mpg and city mpg performance blue color, orange color, respectively.
#
# From above plot It can be notice that Compact, subcompact and midsize vehicle has the highest mpg in both city and highway but with 4 wheel-drive and front-wheel drive and 4 cylinder which is vehicle types of Volkswagen brand but the low dispalcement range. From above plot It can be notice that in respect to the higher litter engine and good performance on highway, it is recommended to choose the ***2seater*** which has 7 diplacement range and 8 cylinder and rear-wheel drive with highway performace around 25-30 mpg.
